# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12396, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 12396 (delta 4), reused 13 (delta 2), pack-reused 12380
# Receiving objects: 100% (12396/12396), 12.18 MiB | 27.42 MiB/s, done.
# Resolving deltas: 100% (8547/8547), done.

# %%
# %cd yolov5/
# Out:
# c:\Users\PC-I\Desktop\AI_Project_Mask_Detection\yolov5

# %%
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
# !python detect.py --source "C:\Users\PC-I\Desktop\AI_Project_Mask_Detection\3.jpg" --weights "C:\Users\PC-I\Desktop\AI_Project_Mask_Detection\last.pt" --project "results" --name "raw"
# Out:
# detect: weights=['C:\\Users\\PC-I\\Desktop\\AI_Project_Mask_Detection\\last.pt'], source=C:\Users\PC-I\Desktop\AI_Project_Mask_Detection\3.jpg, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=results, name=raw, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.1-277-gfdc9d91 Python-3.10.2 torch-1.11.0+cpu CPU
#
# Fusing layers...
# Model summary: 213 layers, 7015519 parameters, 0 gradients
# image 1/1 C:\Users\PC-I\Desktop\AI_Project_Mask_Detection\3.jpg: 384x640 1 mask, Done. (0.326s)
# Speed: 2.0ms pre-process, 326.4ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to results\raw2

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread("C:\\Users\\PC-I\\Desktop\\AI_Project_Mask_Detection\\yolov5\\runs\\detect\\exp4\\3.jpg")
imgplot = plt.imshow(img)

plt.axis(False)
plt.show()
